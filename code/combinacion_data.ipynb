# %% [markdown]
# # Importamos librerias requeridas

# %%
import pandas as pd

# %% [markdown]
# # Cargamos todos los datos transformados

# %% [markdown]
# Cargamos el dataset transformado movies

# %%
file_movies = 'D:\DataScience\PI\Process\Dataset_def\dt_movies.csv'
movies = pd.read_csv(file_movies, index_col=0)
movies.head(2)
# Out:
#      budget   id original_language  \
# 0  30000000  862                en
# 1  30000000  862                en
#
#                                             overview  popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
# 1  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
#
#        revenue  runtime    status tagline  ... id_genero     genero  \
# 0  373554033.0     81.0  Released     NaN  ...        16  Animation
# 1  373554033.0     81.0  Released     NaN  ...        35     Comedy
#
#    id_coleccion      nombre_coleccion  id_companie                 companie  \
# 0       10194.0  Toy Story Collection            3  Pixar Animation Studios
# 1       10194.0  Toy Story Collection            3  Pixar Animation Studios
#
#   iso_3166_1                   country iso_639_1  languaje
# 0         US  United States of America        en   English
# 1         US  United States of America        en   English
#
# [2 rows x 25 columns]

# %% [markdown]
# Cargamos el dataset transformado cast

# %%
file_cast = 'D:\DataScience\PI\Process\Dataset_def\dt_cast.csv'
cast = pd.read_csv(file_cast, index_col=0)
cast.drop_duplicates(inplace=True)
cast.reset_index(inplace=True)
cast.drop(columns='index', inplace=True)
cast
# Out:
#             id         name_actor
# 0          862          Tom Hanks
# 1          862          Tim Allen
# 2          862        Don Rickles
# 3          862         Jim Varney
# 4          862      Wallace Shawn
# ...        ...                ...
# 560699  227506   Iwan Mosschuchin
# 560700  227506  Nathalie Lissenko
# 560701  227506       Pavel Pavlov
# 560702  227506  Aleksandr Chabrov
# 560703  227506        Vera Orlova
#
# [560704 rows x 2 columns]

# %% [markdown]
# Cargamos el dataset transformado crew

# %%
file_crew = 'D:\DataScience\PI\Process\Dataset_def\dt_crew.csv'
crew = pd.read_csv(file_crew, index_col=0)
# ya que los endpoints de la api requiere solo el director de las peliculos, descartamos los trabajos diferentes a este
crew = crew[crew.job == 'Director']
crew.drop_duplicates(inplace=True) # eliminamos los duplicados del dataframe
crew.reset_index(inplace=True) # reiniciamos el index para que queden nuevamente en orden
# ya sabemos que todos los nombres existentes corresponden a los directores 
crew.drop(columns=['index', 'job'], inplace=True) # se elimina la columna job
crew.rename(columns={'name':'name_director'}, inplace=True) # reemplazamos el nombre de la columna name por name_director
crew.head()
# Out:
#       id    name_director
# 0    862    John Lasseter
# 1   8844     Joe Johnston
# 2  15602    Howard Deutch
# 3  31357  Forest Whitaker
# 4  11862    Charles Shyer

# %% [markdown]
# # Procedemos a hacer el merge para obtener un solo dataframe

# %% [markdown]
# Hacemos un left join entre movies, cast y crew mediante el campo id para agregar el nombre de los actores y directores a las peliculas existentes en el dataframe de movies

# %%
merge_df = pd.merge(movies, cast, on='id', how='left')
merge_df = pd.merge(merge_df, crew, on='id', how='left')

# %%
merge_df
# Out:
#             budget     id original_language  \
# 0         30000000    862                en
# 1         30000000    862                en
# 2         30000000    862                en
# 3         30000000    862                en
# 4         30000000    862                en
# ...            ...    ...               ...
# 10241994         0  67758                en
# 10241995         0  67758                en
# 10241996         0  67758                en
# 10241997         0  67758                en
# 10241998         0  67758                en
#
#                                                    overview  popularity  \
# 0         Led by Woody, Andy's toys live happily in his ...   21.946943
# 1         Led by Woody, Andy's toys live happily in his ...   21.946943
# 2         Led by Woody, Andy's toys live happily in his ...   21.946943
# 3         Led by Woody, Andy's toys live happily in his ...   21.946943
# 4         Led by Woody, Andy's toys live happily in his ...   21.946943
# ...                                                     ...         ...
# 10241994  When one of her hits goes wrong, a professiona...    0.903007
# 10241995  When one of her hits goes wrong, a professiona...    0.903007
# 10241996  When one of her hits goes wrong, a professiona...    0.903007
# 10241997  When one of her hits goes wrong, a professiona...    0.903007
# 10241998  When one of her hits goes wrong, a professiona...    0.903007
#
#          release_date      revenue  runtime    status                 tagline  \
# 0          1995-10-30  373554033.0     81.0  Released                     NaN
# 1          1995-10-30  373554033.0     81.0  Released                     NaN
# 2          1995-10-30  373554033.0     81.0  Released                     NaN
# 3          1995-10-30  373554033.0     81.0  Released                     NaN
# 4          1995-10-30  373554033.0     81.0  Released                     NaN
# ...               ...          ...      ...       ...                     ...
# 10241994   2003-08-01          0.0     90.0  Released  A deadly game of wits.
# 10241995   2003-08-01          0.0     90.0  Released  A deadly game of wits.
# 10241996   2003-08-01          0.0     90.0  Released  A deadly game of wits.
# 10241997   2003-08-01          0.0     90.0  Released  A deadly game of wits.
# 10241998   2003-08-01          0.0     90.0  Released  A deadly game of wits.
#
#           ... id_coleccion      nombre_coleccion  id_companie  \
# 0         ...      10194.0  Toy Story Collection            3
# 1         ...      10194.0  Toy Story Collection            3
# 2         ...      10194.0  Toy Story Collection            3
# 3         ...      10194.0  Toy Story Collection            3
# 4         ...      10194.0  Toy Story Collection            3
# ...       ...          ...                   ...          ...
# 10241994  ...          NaN                   NaN         6165
# 10241995  ...          NaN                   NaN         6165
# 10241996  ...          NaN                   NaN         6165
# 10241997  ...          NaN                   NaN         6165
# 10241998  ...          NaN                   NaN         6165
#
#                          companie  iso_3166_1                   country  \
# 0         Pixar Animation Studios          US  United States of America
# 1         Pixar Animation Studios          US  United States of America
# 2         Pixar Animation Studios          US  United States of America
# 3         Pixar Animation Studios          US  United States of America
# 4         Pixar Animation Studios          US  United States of America
# ...                           ...         ...                       ...
# 10241994  American World Pictures          US  United States of America
# 10241995  American World Pictures          US  United States of America
# 10241996  American World Pictures          US  United States of America
# 10241997  American World Pictures          US  United States of America
# 10241998  American World Pictures          US  United States of America
#
#          iso_639_1  languaje        name_actor   name_director
# 0               en   English         Tom Hanks   John Lasseter
# 1               en   English         Tim Allen   John Lasseter
# 2               en   English       Don Rickles   John Lasseter
# 3               en   English        Jim Varney   John Lasseter
# 4               en   English     Wallace Shawn   John Lasseter
# ...            ...       ...               ...             ...
# 10241994        en   English      Joe Sabatino  Mark L. Lester
# 10241995        en   English    Kiko Ellsworth  Mark L. Lester
# 10241996        en   English        Don Swayze  Mark L. Lester
# 10241997        en   English      Peter Dobson  Mark L. Lester
# 10241998        en   English  Darrell Dubovsky  Mark L. Lester
#
# [10241999 rows x 27 columns]
